# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
#from google.colab import drive
#drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
root_path = '/content/gdrive/MyDrive/CNN_upgrad'
data_dir_train = pathlib.Path('/content/gdrive/MyDrive/CNN_upgrad/Train')
data_dir_test = pathlib.Path(root_path + '/Test')

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
#data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
#data_dir_test = pathlib.Path('/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

#data_dir_train = pathlib.Path("Skin cancer ISIC The International Skin Imaging Collaboration/Train")
#data_dir_test = pathlib.Path('Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the datase
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),
    batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

num_classes = 9 # As target class has 9 labels

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 856s 1s/step - loss: 1.8865 - accuracy: 0.2949 - val_loss: 1.4524 - val_accuracy: 0.4447
# Epoch 2/20
# 169/169 [==============================] - 3s 21ms/step - loss: 1.4130 - accuracy: 0.4679 - val_loss: 1.3639 - val_accuracy: 0.5182
# Epoch 3/20
# 169/169 [==============================] - 4s 22ms/step - loss: 1.2427 - accuracy: 0.5449 - val_loss: 1.0947 - val_accuracy: 0.6117
# Epoch 4/20
# 169/169 [==============================] - 4s 22ms/step - loss: 1.0493 - accuracy: 0.6135 - val_loss: 1.0423 - val_accuracy: 0.6273
# Epoch 5/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.8566 - accuracy: 0.6864 - val_loss: 0.9611 - val_accuracy: 0.6570
# Epoch 6/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.7122 - accuracy: 0.7357 - val_loss: 0.8912 - val_accuracy: 0.7023
# Epoch 7/20
# 169/169 [==============================] - 4s 23ms/step - loss: 0.5974 - accuracy: 0.7871 - val_loss: 1.0572 - val_accuracy: 0.6600
# Epoch 8/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.5384 - accuracy: 0.8068 - val_loss: 0.8322 - val_accuracy: 0.7335
# Epoch 9/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.4126 - accuracy: 0.8550 - val_loss: 0.7666 - val_accuracy: 0.7520
# Epoch 10/20
# 169/169 [==============================] - 4s 22ms/step - loss: 0.3724 - accuracy: 0.8694 - val_loss: 0.8054 - val_accuracy: 0.7602
# Epoch 11/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.2990 - accuracy: 0.8911 - val_loss: 0.7720 - val_accuracy: 0.7765
# Epoch 12/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.2469 - accuracy: 0.9130 - val_loss: 0.7338 - val_accuracy: 0.8062
# Epoch 13/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.3090 - accuracy: 0.8863 - val_loss: 0.8842 - val_accuracy: 0.7728
# Epoch 14/20
# 169/169 [==============================] - 4s 21ms/step - loss: 0.2615 - accuracy: 0.9039 - val_loss: 0.7156 - val_accuracy: 0.7936
# Epoch 15/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.2344 - accuracy: 0.9160 - val_loss: 0.6439 - val_accuracy: 0.8255
# Epoch 16/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.1965 - accuracy: 0.9286 - val_loss: 0.7331 - val_accuracy: 0.8174
# Epoch 17/20
# 169/169 [==============================] - 4s 23ms/step - loss: 0.1613 - accuracy: 0.9343 - val_loss: 0.7254 - val_accuracy: 0.8144
# Epoch 18/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.1430 - accuracy: 0.9420 - val_loss: 0.6288 - val_accuracy: 0.8330
# Epoch 19/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.1297 - accuracy: 0.9490 - val_loss: 0.6953 - val_accuracy: 0.8344
# Epoch 20/20
# 169/169 [==============================] - 4s 21ms/step - loss: 0.1367 - accuracy: 0.9447 - val_loss: 0.7693 - val_accuracy: 0.8196

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# **Comment:**
#
# - Training accuracy of the model seems to increase linearly whereas validation accuracy remained stagnant around 55%
# - High training accuracy means the model has learnt the noise in the data as well, however its poor performance on validation data shows lack of generalisability of the model.
# - The above observations confirm the case of overfitting. To mitigate overfitting augmentation technique will be used. Since the training data available is less, we will generate new samples by slightly modifying the existing training data (for eg. flipping the image horizontally/vertically, slightly rotating the image etc) and use them for training the model as well.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

data_augmentation = keras.Sequential([
                                      layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.experimental.preprocessing.RandomRotation(0.1),
                                      layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 7s 29ms/step - loss: 1.7895 - accuracy: 0.3142 - val_loss: 1.4711 - val_accuracy: 0.4313
# Epoch 2/20
# 169/169 [==============================] - 5s 29ms/step - loss: 1.4990 - accuracy: 0.4191 - val_loss: 1.3100 - val_accuracy: 0.4981
# Epoch 3/20
# 169/169 [==============================] - 5s 28ms/step - loss: 1.3890 - accuracy: 0.4659 - val_loss: 1.2769 - val_accuracy: 0.5100
# Epoch 4/20
# 169/169 [==============================] - 5s 30ms/step - loss: 1.3030 - accuracy: 0.4967 - val_loss: 1.3088 - val_accuracy: 0.5026
# Epoch 5/20
# 169/169 [==============================] - 5s 28ms/step - loss: 1.2466 - accuracy: 0.5117 - val_loss: 1.2157 - val_accuracy: 0.5494
# Epoch 6/20
# 169/169 [==============================] - 5s 28ms/step - loss: 1.2278 - accuracy: 0.5352 - val_loss: 1.1277 - val_accuracy: 0.5739
# Epoch 7/20
# 169/169 [==============================] - 5s 31ms/step - loss: 1.1688 - accuracy: 0.5516 - val_loss: 1.1191 - val_accuracy: 0.5761
# Epoch 8/20
# 169/169 [==============================] - 5s 28ms/step - loss: 1.1214 - accuracy: 0.5645 - val_loss: 1.1407 - val_accuracy: 0.5687
# Epoch 9/20
# 169/169 [==============================] - 5s 29ms/step - loss: 1.1025 - accuracy: 0.5738 - val_loss: 1.0870 - val_accuracy: 0.6028
# Epoch 10/20
# 169/169 [==============================] - 5s 28ms/step - loss: 1.0539 - accuracy: 0.5946 - val_loss: 1.1752 - val_accuracy: 0.5902
# Epoch 11/20
# 169/169 [==============================] - 5s 28ms/step - loss: 1.0385 - accuracy: 0.6000 - val_loss: 1.0150 - val_accuracy: 0.6273
# Epoch 12/20
# 169/169 [==============================] - 5s 29ms/step - loss: 0.9775 - accuracy: 0.6267 - val_loss: 1.0162 - val_accuracy: 0.6229
# Epoch 13/20
# 169/169 [==============================] - 5s 28ms/step - loss: 0.9503 - accuracy: 0.6354 - val_loss: 0.9942 - val_accuracy: 0.6392
# Epoch 14/20
# 169/169 [==============================] - 5s 30ms/step - loss: 0.9447 - accuracy: 0.6419 - val_loss: 0.9104 - val_accuracy: 0.6771
# Epoch 15/20
# 169/169 [==============================] - 5s 29ms/step - loss: 0.8421 - accuracy: 0.6754 - val_loss: 0.9128 - val_accuracy: 0.6726
# Epoch 16/20
# 169/169 [==============================] - 5s 28ms/step - loss: 0.8364 - accuracy: 0.6740 - val_loss: 0.9112 - val_accuracy: 0.6793
# Epoch 17/20
# 169/169 [==============================] - 5s 30ms/step - loss: 0.7801 - accuracy: 0.6997 - val_loss: 0.8471 - val_accuracy: 0.6964
# Epoch 18/20
# 169/169 [==============================] - 5s 28ms/step - loss: 0.7701 - accuracy: 0.7092 - val_loss: 0.9007 - val_accuracy: 0.6696
# Epoch 19/20
# 169/169 [==============================] - 5s 29ms/step - loss: 0.7926 - accuracy: 0.6968 - val_loss: 0.7985 - val_accuracy: 0.7246
# Epoch 20/20
# 169/169 [==============================] - 5s 28ms/step - loss: 0.7370 - accuracy: 0.7181 - val_loss: 0.7647 - val_accuracy: 0.7558

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# **Comment:**
# - With the help of augmented data, the problem of overfitting is mitigated.
# - Training and validation accuracy of the above model are in the same range.
# - The model is performing poorly both on training data and validation data- i.e. the model is underfitting now.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

from glob import glob
path_list = [ x for x in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
lesion_list = [ os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesion_list))
# Out:
# 2239

# %%
df_dict_original = dict(zip(path_list, lesion_list))
print(list(df_dict_original.items())[:2])
# Out:
# [('/content/gdrive/MyDrive/CNN_upgrad/Train/actinic keratosis/ISIC_0026729.jpg', 'actinic keratosis'), ('/content/gdrive/MyDrive/CNN_upgrad/Train/actinic keratosis/ISIC_0026575.jpg', 'actinic keratosis')]

# %%
original_df = pd.DataFrame(list(df_dict_original.items()), columns=['Path','Label'])
original_df.head()
# Out:
#                                                 Path              Label
# 0  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 1  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 2  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 3  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 4  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# dtype: int64

# %%
original_df[['Label']].value_counts(normalize=True)
# Out:
# Label
# pigmented benign keratosis    0.206342
# melanoma                      0.195623
# basal cell carcinoma          0.167932
# nevus                         0.159446
# squamous cell carcinoma       0.080840
# vascular lesion               0.062081
# actinic keratosis             0.050916
# dermatofibroma                0.042430
# seborrheic keratosis          0.034390
# dtype: float64

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# **Comment:**
# - 'seborrheic keratosis' has the least number of samples
# - the classes 'pigmented benign keratosis' and 'melanoma' dominate the data with 20.6% and 19.5% samples respectively.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D1BE5706E60>: 100%|██████████| 500/500 [00:20<00:00, 24.83 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D1ACA77FD30>: 100%|██████████| 500/500 [00:21<00:00, 22.92 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D1B5C476290>: 100%|██████████| 500/500 [00:23<00:00, 21.05 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7D1B591E3970>: 100%|██████████| 500/500 [01:22<00:00,  6.03 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7D1B5C476B90>: 100%|██████████| 500/500 [01:10<00:00,  7.10 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D1BE5705D50>: 100%|██████████| 500/500 [00:17<00:00, 28.57 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7D1B596338E0>: 100%|██████████| 500/500 [00:41<00:00, 12.06 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D1B5C476290>: 100%|██████████| 500/500 [00:16<00:00, 29.69 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_upgrad/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D1AF4B43400>: 100%|██████████| 500/500 [00:17<00:00, 27.87 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 9000

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:2]
# Out:
# ['/content/gdrive/MyDrive/CNN_upgrad/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026040.jpg_76c41d4e-da9b-44c4-a3a1-78cb807c722a.jpg',
#  '/content/gdrive/MyDrive/CNN_upgrad/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026857.jpg_fbcd073e-fb3b-46e6-a856-caa7fe31611f.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:2]
# Out:
# ['actinic keratosis', 'actinic keratosis']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
new_df.shape
# Out:
# <ipython-input-33-c1e5e8a551a2>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)
# (11239, 2)

# %%
new_df.head()
# Out:
#                                                 Path              Label
# 0  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 1  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 2  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 3  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis
# 4  /content/gdrive/MyDrive/CNN_upgrad/Train/actin...  actinic keratosis

# %%
# Checking the class distribution after adding 500 samples per label
new_df['Label'].value_counts(normalize=True)
# Out:
# pigmented benign keratosis    0.130083
# melanoma                      0.127947
# basal cell carcinoma          0.122431
# nevus                         0.120740
# squamous cell carcinoma       0.105081
# vascular lesion               0.101344
# actinic keratosis             0.099119
# dermatofibroma                0.097429
# seborrheic keratosis          0.095827
# Name: Label, dtype: float64

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    1462
# melanoma                      1438
# basal cell carcinoma          1376
# nevus                         1357
# squamous cell carcinoma       1181
# vascular lesion               1139
# actinic keratosis             1114
# dermatofibroma                1095
# seborrheic keratosis          1077
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
# if no changes made

# data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 8992 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 11239 files belonging to 9 classes.
# Using 2247 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 281/281 [==============================] - 57s 190ms/step - loss: 1.7797 - accuracy: 0.3169 - val_loss: 1.4933 - val_accuracy: 0.4143
# Epoch 2/30
# 281/281 [==============================] - 53s 184ms/step - loss: 1.3965 - accuracy: 0.4560 - val_loss: 1.2804 - val_accuracy: 0.5162
# Epoch 3/30
# 281/281 [==============================] - 52s 182ms/step - loss: 1.2969 - accuracy: 0.5056 - val_loss: 1.2101 - val_accuracy: 0.5385
# Epoch 4/30
# 281/281 [==============================] - 53s 185ms/step - loss: 1.2127 - accuracy: 0.5389 - val_loss: 1.2556 - val_accuracy: 0.5327
# Epoch 5/30
# 281/281 [==============================] - 51s 178ms/step - loss: 1.1616 - accuracy: 0.5592 - val_loss: 1.0744 - val_accuracy: 0.5915
# Epoch 6/30
# 281/281 [==============================] - 53s 186ms/step - loss: 1.1115 - accuracy: 0.5783 - val_loss: 1.1777 - val_accuracy: 0.5701
# Epoch 7/30
# 281/281 [==============================] - 53s 186ms/step - loss: 1.0522 - accuracy: 0.6009 - val_loss: 1.0266 - val_accuracy: 0.6204
# Epoch 8/30
# 281/281 [==============================] - 54s 188ms/step - loss: 1.0036 - accuracy: 0.6147 - val_loss: 1.0583 - val_accuracy: 0.6150
# Epoch 9/30
# 281/281 [==============================] - 52s 180ms/step - loss: 0.9520 - accuracy: 0.6382 - val_loss: 0.8692 - val_accuracy: 0.6720
# Epoch 10/30
# 281/281 [==============================] - 53s 185ms/step - loss: 0.8946 - accuracy: 0.6628 - val_loss: 0.8184 - val_accuracy: 0.6871
# Epoch 11/30
# 281/281 [==============================] - 53s 185ms/step - loss: 0.8568 - accuracy: 0.6763 - val_loss: 0.8662 - val_accuracy: 0.6787
# Epoch 12/30
# 281/281 [==============================] - 51s 179ms/step - loss: 0.7992 - accuracy: 0.7028 - val_loss: 0.7235 - val_accuracy: 0.7308
# Epoch 13/30
# 281/281 [==============================] - 52s 181ms/step - loss: 0.7507 - accuracy: 0.7143 - val_loss: 0.7332 - val_accuracy: 0.7374
# Epoch 14/30
# 281/281 [==============================] - 50s 175ms/step - loss: 0.7118 - accuracy: 0.7329 - val_loss: 0.7066 - val_accuracy: 0.7334
# Epoch 15/30
# 281/281 [==============================] - 51s 179ms/step - loss: 0.7195 - accuracy: 0.7362 - val_loss: 0.7115 - val_accuracy: 0.7245
# Epoch 16/30
# 281/281 [==============================] - 52s 180ms/step - loss: 0.6709 - accuracy: 0.7513 - val_loss: 0.7293 - val_accuracy: 0.7397
# Epoch 17/30
# 281/281 [==============================] - 50s 174ms/step - loss: 0.6444 - accuracy: 0.7645 - val_loss: 0.6263 - val_accuracy: 0.7739
# Epoch 18/30
# 281/281 [==============================] - 52s 184ms/step - loss: 0.6063 - accuracy: 0.7734 - val_loss: 0.6349 - val_accuracy: 0.7735
# Epoch 19/30
# 281/281 [==============================] - 52s 181ms/step - loss: 0.5600 - accuracy: 0.7877 - val_loss: 0.6125 - val_accuracy: 0.7588
# Epoch 20/30
# 281/281 [==============================] - 51s 180ms/step - loss: 0.5703 - accuracy: 0.7854 - val_loss: 0.5352 - val_accuracy: 0.8104
# Epoch 21/30
# 281/281 [==============================] - 52s 182ms/step - loss: 0.5629 - accuracy: 0.7919 - val_loss: 0.4999 - val_accuracy: 0.8095
# Epoch 22/30
# 281/281 [==============================] - 52s 183ms/step - loss: 0.5271 - accuracy: 0.8035 - val_loss: 0.4736 - val_accuracy: 0.8211
# Epoch 23/30
# 281/281 [==============================] - 52s 181ms/step - loss: 0.5035 - accuracy: 0.8118 - val_loss: 0.4980 - val_accuracy: 0.8149
# Epoch 24/30
# 281/281 [==============================] - 52s 181ms/step - loss: 0.4899 - accuracy: 0.8201 - val_loss: 0.4483 - val_accuracy: 0.8429
# Epoch 25/30
# 281/281 [==============================] - 53s 186ms/step - loss: 0.4523 - accuracy: 0.8332 - val_loss: 0.5231 - val_accuracy: 0.8046
# Epoch 26/30
# 281/281 [==============================] - 51s 175ms/step - loss: 0.4644 - accuracy: 0.8245 - val_loss: 0.4851 - val_accuracy: 0.8229
# Epoch 27/30
# 281/281 [==============================] - 52s 183ms/step - loss: 0.4772 - accuracy: 0.8206 - val_loss: 0.4498 - val_accuracy: 0.8349
# Epoch 28/30
# 281/281 [==============================] - 51s 180ms/step - loss: 0.4350 - accuracy: 0.8406 - val_loss: 0.5234 - val_accuracy: 0.8126
# Epoch 29/30
# 281/281 [==============================] - 52s 182ms/step - loss: 0.4357 - accuracy: 0.8419 - val_loss: 0.4806 - val_accuracy: 0.8300
# Epoch 30/30
# 281/281 [==============================] - 50s 176ms/step - loss: 0.4092 - accuracy: 0.8473 - val_loss: 0.4407 - val_accuracy: 0.8336

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# **Comment:**
# - In the final model, there is no sign of underfitting/overfitting.
# - Class rebalanced improved the model performance on both training and validation data.
# - In 30 epochs, the final model is able to achieve 80% training accuracy and 77% validation accuracy.
# - The low difference between the training accuracy and validation accuracy signifies that the final CNN model is able to generalize well.
# - Inclusion of batch normalization is degrading the accuracy of the final model, hence it is not used.
